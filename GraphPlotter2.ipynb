# %% [markdown]
# # Graph Plotter
# #### This script plots simply graphs given y and x values

# %% [markdown]
# ### Imports

# %%
from matplotlib import pyplot as plt
import matplotlib.ticker as ticker

# %% [markdown]
# ### Define the function to plot

# %%
def plot(x, y, x_label, y_label, tick_amount):
    fig, ax = plt.subplots(figsize=(7,5))
    plt.plot(x, y)
    plt.scatter(x, y)
    ax.axes.set_xlabel(x_label)
    ax.axes.set_ylabel(y_label)
    ax.xaxis.set_major_locator(ticker.MultipleLocator(tick_amount))
    ax.set_xlim(left=1, right=max(x))
    ax.set_ylim(bottom=0)
    plt.show()
    
def plot2(x, y, y2, x_label, y_label, tick_amount, ylabel, y2label):
    fig, ax = plt.subplots(figsize=(7,5))
    plt.plot(x, y)
    plt.scatter(x, y, label=ylabel)
    plt.plot(x, y2)
    plt.scatter(x, y2, label=y2label)
    ax.legend(fontsize='x-large')
    ax.axes.set_xlabel(x_label)
    ax.axes.set_ylabel(y_label)
    ax.xaxis.set_major_locator(ticker.MultipleLocator(tick_amount))
    ax.set_xlim(left=1, right=max(x))
    ax.set_ylim(bottom=0)
    plt.show()

# %% [markdown]
# ### Do the required plots

# %%
# CPU - lab - time to generate points
serial_points_time = [
    4.29153e-05,
    4.19617e-05,
    4.22001e-05,
    4.19617e-05,
    4.19617e-05,
    4.31538e-05,
    4.98295e-05,
    4.48227e-05,
    4.60148e-05,
    5.00679e-05,
    6.19888e-05,
    8.01086e-05,
    0.000124216,
    0.000203133,
    0.00037694,
    0.000897169,
    0.00141597,
    0.0027709,
    0.00563216,
    0.0125279,
    0.0263779,
    0.0526612,
    0.104839,
    0.20916,
    0.426975,
    0.837677,
]

plot(list(range(1,27)), serial_points_time, 'Iterations','Time (s)', 1)

# %%
serial_image_time = [
    0.00659204,
    0.00654411,
    0.00672507,
    0.00674009,
    0.00681591,
    0.00700092,
    0.00716805,
    0.00749183,
    0.00772786,
    0.00809693,
    0.00866318,
    0.00924993,
    0.0105019,
    0.0125518,
    0.016247,
    0.0226982,
    0.0344231,
    0.055238,
    0.0934188,
    0.161139,
    0.282918,
    0.50772,
    0.911524,
    1.65654,
    3.0129,
    5.51501,
]
plot(list(range(1,27)), serial_image_time, 'Iterations','Time (s)', 1)

# %%
parallel_points_time = [
    0.120088,
    0.115712,
    0.0983112,
    0.0946579,
    0.0946469,
    0.0945401,
    0.097302,
    0.094537,
    0.0958769,
    0.0976551,
    0.101143,
    0.0941782,
    0.0943329,
    0.0977371,
    0.096869,
    0.0970049,
    0.096359,
    0.098443,
    0.11326,
    0.105002,
    0.112553,
    0.130339,
    0.161704,
    0.229343,
    0.357573,
    0.620172,
]
plot(list(range(1,27)), parallel_points_time, 'Iterations','Time (s)', 1)

# %%
parallel_image_time = [
    0.0746951,
    0.073643,
    0.074038,
    0.0734961,
    0.074095,
    0.0732079,
    0.074193,
    0.074106,
    0.0735309,
    0.0732229,
    0.0737441,
    0.0729651,
    0.073468,
    0.0738189,
    0.073776,
    0.0734639,
    0.0743468,
    0.0748422,
    0.0769761,
    0.080945,
    0.0895588,
    0.104369,
    0.135713,
    0.195208,
    0.291632,
    0.478835,
]
plot(list(range(1,27)), parallel_image_time, 'Iterations','Time (s)', 1)

# %%
plot2(list(range(1,27)), serial_points_time, parallel_points_time, 'Iterations','Time (s)', 1,
     ylabel='Serial', y2label='Parallel')

# %%
plot2(list(range(1,27)), serial_image_time, parallel_image_time, 'Iterations','Time (s)', 1,
     ylabel='Serial', y2label='Parallel')
